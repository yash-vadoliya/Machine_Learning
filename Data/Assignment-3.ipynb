# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# from sklearn.linear_model import LinearRegression
from sklearn import linear_model

rec = pd.read_csv("Data_Advertising.csv")
# print(data)

# TV 
x = np.array(data.TV).reshape(-1,1)
y = np.array(data.sales).reshape(-1,1)

liner_regression_model = linear_model.LinearRegression()
liner_regression_model.fit(x,y)

xtest = x
ytest_result = liner_regression_model.predict(xtest)

plt.scatter(x,y,color="red")
plt.scatter(xtest,ytest_result,color="teal")
plt.title("TV")
plt.xlabel("TV")
plt.ylabel("sales")
plt.show()

# Radio

x1 = np.array(data.TV).reshape(-1,1)
y1 = np.array(data.sales).reshape(-1,1)

liner_regression_model = linear_model.LinearRegression()
liner_regression_model.fit(x1,y1)

x1test = x1
y1test_result = liner_regression_model.predict(x1test)

plt.scatter(x1,y1,color="red")
plt.scatter(x1test,y1test_result,color="teal")
plt.title("Radio")
plt.xlabel("Radio")
plt.ylabel("sales")
plt.show()

# Newspaper

x2 = np.array(data.newspaper).reshape(-1,1)
y2 = np.array(data.sales).reshape(-1,1)

liner_regression_model = linear_model.LinearRegression()
liner_regression_model.fit(x2,y2)

x2test = x2
y1test_result = liner_regression_model.predict(x2test)

plt.scatter(x2,y2,color="red")
plt.scatter(x2test,y2test_result,color="teal")
plt.title("Newspaper")
plt.xlabel("Newspaper")
plt.ylabel("sales")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3156/102444669.py in <module>
#      55
#      56 plt.scatter(x2,y2,color="red")
# ---> 57 plt.scatter(x2test,y2test_result,color="teal")
#      58 plt.title("Newspaper")
#      59 plt.xlabel("Newspaper")
#
# NameError: name 'y2test_result' is not defined
